# %%
import sys
import os

PROJECT_ROOT = os.getcwd()
sys.path.insert(0, PROJECT_ROOT)

print("Project root in sys.path:", PROJECT_ROOT)
# Out:
# Project root in sys.path: g:\Research-Chatbot\RP_SmartDairyFarm_Flask_AIML

# %%
import controllers
print(controllers.__file__)
# Out:
# g:\Research-Chatbot\RP_SmartDairyFarm_Flask_AIML\controllers\__init__.py

# %%
# Import RAG query function now
from controllers.rag_query import rag_answer

# Test a query
query = "ශ්‍රී ලංකාවේ බහුලව භාවිත වන ගව ආහාර කුමක්ද?"
answer = rag_answer(query)

print("🔊 Chatbot Response:\n")
print(answer)
# Out:
# Loaded 15 docs from breeding.json
# Loaded 15 docs from diseases.json
# Loaded 20 docs from feeding.json
# Loaded 15 docs from milk_production.json
# ✅ Total knowledge documents loaded: 65
# 🔊 Chatbot Response:
#
# ශ්‍රී ලංකාවේ බහුලව භාවිත වන ගව ආහාර ගැන අද මම ඔබට විස්තර කරන්නෙමි. මෙරට ගව පාලකයෝ බහුලව නේපියර් තෘණ, ගිනී තෘණ, රයිස් බ්‍රෑන් සහ පොල් පූනක් භාවිත කරනු ලබයි. මෙම ආහාර ගවයින්ට පෝෂණය සපයන අතර, ගව පාලකයන්ට අඩු වියදම් ආහාර ලබා දෙයි.
#
# මෙම ආහාර තෝරා ගැනීමට හේතු ගවයින්ට අවශ්‍ය පෝෂක පදාර්ථ සපයන බැවින් වේ. නේපියර් තෘණ සහ ගිනී තෘණ ගවයින්ට අවශ්‍ය ප්‍රෝටීන් සහ ෆයිබර් සපයන අතර, රයිස් බ්‍රෑන් සහ පොල් පූනක් ගවයින්ට අවශ්‍ය ශක්ති සහ පෝෂක පදාර්ථ සපයයි.
#
# මෙම ආහාර භාවිත කිරීම ගව පාලකයන්ට ආර්ථික වාසි ද සපයයි. නේපියර් තෘණ සහ ගිනී තෘණ ගෙවත්තේ වගා කල හැකි අතර, රයිස් බ්‍රෑන් සහ පොල් පූනක් අඩු වියදම් ආහාර පද්ධති වේ. මෙම ආහාර භාවිත කිරීම ගව පාලකයන්ට අඩු වියදම් ආහාර ලබා දෙයි, එම නිසා ඔවුන්ට ආර්ථික වාසි සපයයි.
#
# මෙම ආහාර භාවිත කිරීම ගවයින්ට ද වාසි සපයයි. නේපියර් තෘණ සහ ගිනී තෘණ ගවයින්ට අවශ්‍ය පෝෂක පදාර්ථ සපයන අතර, රයිස් බ්‍රෑන් සහ පොල් පූනක් ගවයින්ට අවශ්‍ය ශක්ති සහ පෝෂක පදාර්ථ සපයයි. මෙම ආහාර භාවිත කිරීම ගවයින්ට සුවසේ හා සෞඛ්‍ය සම්පන්න ජීවිතයක් ගත කිරීමට උපකාරී වේ.
#
# මෙම ආහාර භාවිත කිරීම ගව පාලකයන්ට ප්‍රායෝගික උපදෙස් ද සපයයි. ගව පාලකයන්ට මෙම ආහාර භාවිත කිරීම ගවයින්ට අවශ්‍ය පෝෂක පදාර්ථ සපයන බැවින් වාසි සපයයි. මෙම ආහාර භාවිත කිරීම ගව පාලකයන්ට අඩු වියදම් ආහාර ලබා දෙයි, එම න
