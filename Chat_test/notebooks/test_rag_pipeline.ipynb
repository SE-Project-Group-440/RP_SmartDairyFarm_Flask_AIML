# %%
import os
os.chdir("..")  # move to project root
print(os.getcwd())
# Out:
# g:\Research-Chatbot\RP_SmartDairyFarm_Flask_AIML\Chat_test

# %%
# %pip install faiss-cpu
# Out:
# Requirement already satisfied: faiss-cpu in f:\python\lib\site-packages (1.13.2)
# Requirement already satisfied: numpy<3.0,>=1.25.0 in f:\python\lib\site-packages (from faiss-cpu) (2.3.5)
# Requirement already satisfied: packaging in f:\python\lib\site-packages (from faiss-cpu) (25.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Import RAG query function now
from scripts.rag_query import rag_answer

# Test a query
query = "ශ්‍රී ලංකාවේ බහුලව භාවිත වන ගව ආහාර කුමක්ද?"
answer = rag_answer(query)

print("🔊 Chatbot Response:\n")
print(answer)
# Out:
# Loaded 50 docs from breeding.json
# Loaded 35 docs from cow_types.json
# Loaded 50 docs from diseases.json
# Loaded 35 docs from feeding.json
# Loaded 5 docs from management.json
# Loaded 90 docs from milk_production.json
# ✅ Total knowledge documents loaded: 265
# Loaded 50 docs from breeding.json
# Loaded 35 docs from cow_types.json
# Loaded 50 docs from diseases.json
# Loaded 35 docs from feeding.json
# Loaded 5 docs from management.json
# Loaded 90 docs from milk_production.json
# ✅ Total knowledge documents loaded: 265
# 🔊 Chatbot Response:
#
# ශ්‍රී ලංකාවේ බහුලව භාවිත වන ගව ආහාර ගැන අමර ගව පාලකයන් දැනුවත් කිරීම සඳහා, මම මෙම තොරතුරු සපයමි.
#
# ප්‍රථමයෙන්, නේපියර් තෘණ යනු ශ්‍රී ලංකාවේ බහුලව භාවිත වන ගව ආහාරයකි. මෙම තෘණ වගා කිරීම අඩු වියදම් සහ අඩු ප්‍රමාණයෙන් ඉඩම් අවශ්‍ය වන බැවින්, ගව පාලකයන්ට එය ප්‍රයෝජනයක් වේ. තවද, ගිනී තෘණ ද බහුලව භාවිත වේ. මෙම තෘණ ද අඩු වියදම් සහ අඩු ප්‍රමාණයෙන් ඉඩම් අවශ්‍ය වන බැවින්, ගව පාලකයන්ට එය ප්‍රයෝජනයක් වේ.
#
# රයිස් බ්‍රෑන් ද ශ්‍රී ලංකාවේ බහුලව භාවිත වන ගව ආහාරයකි. මෙම ආහාර ගව පාලකයන්ට ප්‍රයෝජනයක් වන්නේ, එය අඩු වියදම් සහ අඩු ප්‍රමාණයෙන් ඉඩම් අවශ්‍ය වන බැවින් ය. තවද, පොල් පූනක් ද ශ්‍රී ලංකාවේ බහුලව භාවිත වන ගව ආහාරයකි. මෙම ආහාර ගව පාලකයන්ට ප්‍රයෝජනයක් වන්නේ, එය අඩු වියදම් සහ අඩු ප්‍රමාණයෙන් ඉඩම් අවශ්‍ය වන බැවින් ය.
#
# මේ ආකාරයට, නේපියර් තෘණ, ගිනී තෘණ, රයිස් බ්‍රෑන් සහ පොල් පූනක් යන ආහාර ශ්‍රී ලංකාවේ බහුලව භාවිත වන ගව ආහාර වේ. මෙම ආහාර ගව පාලකයන්ට ප්‍රයෝජනයක් වන්නේ, එය අඩු වියදම් සහ අඩු ප්‍රමාණයෙන් ඉඩම් අවශ්‍ය වන බැවින් ය.
