# %%
import os
os.chdir("..")  # move to project root
print(os.getcwd())
# Out:
# g:\Chatbot\notebook\Chat_test

# %%
# Import RAG query function now
from scripts.rag_query import rag_answer

# Test a query
query = "ශ්‍රී ලංකාවේ බහුලව භාවිත වන ගව ආහාර කුමක්ද?"
answer = rag_answer(query)

print("🔊 Chatbot Response:\n")
print(answer)
# Out:
# 🔊 Chatbot Response:
#
# ශ්‍රී ලංකාවේ බහුලව භාවිත වන ගව ආහාර ගව පාලකයන් විසින් තේරුම් ගත හැකි ආකාරයට මම පහත දැක්වෙන ආහාර ප්‍රකාශ කරනවා.
#
# 1. **තෘණ වගා**: ගෙවත්තේ තෘණ වගා කිරීම මඟින් ගවයන්ට ආහාර සපයා ගැනීම පහසු වේ. තෘණ වගා මඟින් ගව පාලකයන්ට ආහාර වියදම අඩු කර ගත හැක.
#
# 2. **දේශීය ආහාර**: දේශීය ආහාර භාවිතය මඟින් ගව පාලකයන්ට ආහාර වියදම අඩු කර ගත හැක. දේශීය ආහාර මඟින් ගවයන්ට පෝෂණ සපයා ගැනීම පහසු වේ.
#
# 3. **ගව ආහාර මිශ්‍රණ**: ගව ආහාර මිශ්‍රණ මඟින් ගව පාලකයන්ට ආහාර වියදම අඩු කර ගත හැක. ගව ආහාර මිශ්‍රණ මඟින් ගවයන්ට පෝෂණ සපයා ගැනීම පහසු වේ.
#
# මෙම ආහාර ප්‍රකාශ මඟින් ගව පාලකයන්ට ආහාර වියදම අඩු කර ගත හැක. මෙම ආහාර ප්‍රකාශ මඟින් ගවයන්ට පෝෂණ සපයා ගැනීම පහසු වේ.
